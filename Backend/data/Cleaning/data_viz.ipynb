# %%
import pandas as pd
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

import matplotlib.pyplot as plt
import numpy as np

# %%
#https://developer.spotify.com/documentation/web-api/reference/#/operations/get-audio-features
df_stats = pd.read_csv("data/Weekdays/Stats_viz.csv")
df_stats.head()
# Out:
#    danceability    energy     key  loudness  speechiness  acousticness  \
# 0      0.657461  0.609258  5.2817 -7.500937     0.141651      0.247811
# 1      0.655133  0.614405  5.2484 -7.433977     0.147915      0.249767
# 2      0.651133  0.611810  5.3107 -7.632939     0.147637      0.247034
# 3      0.650636  0.612643  5.2473 -7.689965     0.152415      0.254143
# 4      0.650832  0.626252  5.2427 -7.405199     0.144472      0.241053
#
#    instrumentalness  liveness   valence       tempo  duration_ms  \
# 0          0.052051  0.187337  0.452291  121.448847  212383.5268
# 1          0.052430  0.192777  0.450049  121.370097  214232.5865
# 2          0.059010  0.193416  0.441818  121.043238  215316.5980
# 3          0.065514  0.194838  0.443261  120.665653  216911.3803
# 4          0.055978  0.194875  0.457499  121.065582  217015.1031
#
#    time_signature day_of_week  hour_of_day  hour_of_week
# 0          3.9236      Monday            0             0
# 1          3.9262      Monday            1             1
# 2          3.9273      Monday            2             2
# 3          3.9258      Monday            3             3
# 4          3.9185      Monday            4             4

# %%
df_stats.plot(x = "hour_of_week", y = "time_signature")
# Out:
# <AxesSubplot:xlabel='hour_of_week'>

# %%
fig = plt.figure(figsize=(18,7))
ax = fig.add_subplot()
plt.margins(x = 0)
plt.plot(df_stats['hour_of_week'], df_stats['danceability'], c = "magenta", lw = 2)
ax.set_facecolor('aliceblue')
ax.grid(color = 'lightgray', alpha = 1)
ax.set_title("Danceability", fontsize = 18)
plt.xlabel('Hour of week', fontsize = 15, labelpad = 32)
plt.ylabel('Danceability', fontsize = 15)

plt.xticks(np.arange(0, 168, 6.0))
plt.axvline(x = 24, alpha = 0.7, linewidth = 3.9, c = 'dimgray')
plt.axvline(x = 48, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 72, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 96, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 120, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 144, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')


plt.figtext(0.1799, 0.05, 'Monday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.113, 0.05, 'Tuesday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.223, 0.05, 'Wednesday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.335, 0.05, 'Thursday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.448, 0.05, 'Friday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.56, 0.05, 'Saturday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.67, 0.05, 'Sunday', wrap = True, horizontalalignment = 'center', fontsize = 12)
# Out:
# Text(0.8499000000000001, 0.05, 'Sunday')

# %%
fig = plt.figure(figsize=(18,7))
ax = fig.add_subplot()
plt.margins(x = 0)
plt.plot(df_stats['hour_of_week'], df_stats['energy'], c = "darkturquoise", lw = 2)
ax.set_facecolor('whitesmoke')
ax.grid(color = 'lightgray', alpha = 1)
ax.set_title("Energy", fontsize = 18)
plt.xlabel('Hour of week', fontsize = 15, labelpad = 32)
plt.ylabel('Energy', fontsize = 15)

plt.xticks(np.arange(0, 168, 6.0))
plt.axvline(x = 24, alpha = 0.7, linewidth = 3.9, c = 'dimgray')
plt.axvline(x = 48, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 72, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 96, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 120, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 144, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')


plt.figtext(0.1799, 0.05, 'Monday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.113, 0.05, 'Tuesday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.223, 0.05, 'Wednesday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.335, 0.05, 'Thursday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.448, 0.05, 'Friday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.56, 0.05, 'Saturday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.67, 0.05, 'Sunday', wrap = True, horizontalalignment = 'center', fontsize = 12)
# Out:
# Text(0.8499000000000001, 0.05, 'Sunday')

# %%
fig = plt.figure(figsize=(18,7))
ax = fig.add_subplot()
plt.margins(x = 0)
plt.plot(df_stats['hour_of_week'], df_stats['loudness'], c = "goldenrod", lw = 2)
ax.set_facecolor('ghostwhite')
ax.grid(color = 'lightgray', alpha = 1)
ax.set_title("Loudness", fontsize = 18)
plt.xlabel('Hour of week', fontsize = 15, labelpad = 32)
plt.ylabel('Loudness', fontsize = 15)

plt.xticks(np.arange(0, 168, 6.0))
plt.axvline(x = 24, alpha = 0.7, linewidth = 3.9, c = 'dimgray')
plt.axvline(x = 48, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 72, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 96, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 120, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 144, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')


plt.figtext(0.1799, 0.05, 'Monday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.113, 0.05, 'Tuesday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.223, 0.05, 'Wednesday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.335, 0.05, 'Thursday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.448, 0.05, 'Friday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.56, 0.05, 'Saturday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.67, 0.05, 'Sunday', wrap = True, horizontalalignment = 'center', fontsize = 12)
# Out:
# Text(0.8499000000000001, 0.05, 'Sunday')

# %%
fig = plt.figure(figsize=(18,7))
ax = fig.add_subplot()
plt.margins(x = 0)
plt.plot(df_stats['hour_of_week'], df_stats['acousticness'], c = "peru", lw = 2)
ax.set_facecolor('linen')
ax.grid(color = 'lightgray', alpha = 1)
ax.set_title("Acousticness", fontsize = 18)
plt.xlabel('Hour of week', fontsize = 15, labelpad = 32)
plt.ylabel('Acousticness', fontsize = 15)

plt.xticks(np.arange(0, 168, 6.0))
plt.axvline(x = 24, alpha = 0.7, linewidth = 3.9, c = 'dimgray')
plt.axvline(x = 48, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 72, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 96, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 120, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 144, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')


plt.figtext(0.1799, 0.05, 'Monday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.113, 0.05, 'Tuesday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.223, 0.05, 'Wednesday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.335, 0.05, 'Thursday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.448, 0.05, 'Friday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.56, 0.05, 'Saturday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.67, 0.05, 'Sunday', wrap = True, horizontalalignment = 'center', fontsize = 12)
# Out:
# Text(0.8499000000000001, 0.05, 'Sunday')

# %%
fig = plt.figure(figsize=(18,7))
ax = fig.add_subplot()
plt.margins(x = 0)
plt.plot(df_stats['hour_of_week'], df_stats['valence'], c = "#FAC24B", lw = 2)
ax.set_facecolor('azure')
ax.grid(color = 'lightgray', alpha = 1)
ax.set_title("Valence", fontsize = 18)
plt.xlabel('Hour of week', fontsize = 15, labelpad = 32)
plt.ylabel('Valence', fontsize = 15)

plt.xticks(np.arange(0, 168, 6.0))
plt.axvline(x = 24, alpha = 0.7, linewidth = 3.9, c = 'dimgray')
plt.axvline(x = 48, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 72, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 96, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 120, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')
plt.axvline(x = 144, alpha = 0.7, linewidth = 3.9, c = 'dimgrey')


plt.figtext(0.1799, 0.05, 'Monday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.113, 0.05, 'Tuesday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.223, 0.05, 'Wednesday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.335, 0.05, 'Thursday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.448, 0.05, 'Friday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.56, 0.05, 'Saturday', wrap = True, horizontalalignment = 'center', fontsize = 12)
plt.figtext(0.1799 + 0.67, 0.05, 'Sunday', wrap = True, horizontalalignment = 'center', fontsize = 12)
# Out:
# Text(0.8499000000000001, 0.05, 'Sunday')

# %%
import pandas as pd
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
raw0_df = pd.read_csv('data/raw2_0.csv')
raw1_df = pd.read_csv('data/raw2_1.csv')

# %%
raw0_df.head()
# Out:
#    Unnamed: 0                          track_id_clean  danceability    energy  \
# 0           0  t_1d93867d-ec01-4dd1-a1b5-07713f75571a      0.711919  0.399499
# 1           1  t_022ac379-7d9e-4980-a1df-f21c14c71fbc      0.293747  0.407205
# 2           2  t_b2d43fd4-c06a-4a83-a4db-5e4069a33d7f      0.451133  0.962321
# 3           3  t_b2d43fd4-c06a-4a83-a4db-5e4069a33d7f      0.451133  0.962321
# 4           4  t_1f1b80aa-54de-4b8e-bdc1-1f5e515f6af4      0.651450  0.766461
#
#    loudness  speechiness  acousticness  instrumentalness  liveness   valence  \
# 0    -9.551     0.028237      0.159065          0.000377  0.088130  0.799496
# 1   -11.575     0.030752      0.025825          0.000219  0.085159  0.037802
# 2    -3.947     0.073428      0.018844          0.000003  0.276815  0.376587
# 3    -3.947     0.073428      0.018844          0.000003  0.276815  0.376587
# 4    -9.935     0.029894      0.206378          0.001034  0.362067  0.948500
#
#         tempo  duration_ms  time_signature        date  hour_of_day  \
# 0   97.917999     191636.0               4  2018-07-15            0
# 1  101.052002     235067.0               4  2018-07-15            0
# 2  131.434998     323707.0               4  2018-07-15            0
# 3  131.434998     323707.0               4  2018-07-15            0
# 4  116.739998     242107.0               4  2018-07-15            0
#
#    day_of_week    GROUP
# 0            0  Evening
# 1            0  Evening
# 2            0  Evening
# 3            0  Evening
# 4            0  Evening

# %%
raw0_df = pysqldf("SELECT *, strftime('%w', date) AS day_of_week FROM raw0_df")
raw1_df = pysqldf("SELECT *, strftime('%w', date) AS day_of_week FROM raw1_df")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/lejaja9/Documents/G14/Friiiiiiiiiday/data_clean.ipynb Cell 4' in <module>
#       <a href='vscode-notebook-cell:/Users/lejaja9/Documents/G14/Friiiiiiiiiday/data_clean.ipynb#ch0000004?line=0'>1</a> raw0_df = pysqldf("SELECT *, strftime('%w', date) AS day_of_week FROM raw0_df")
# ----> <a href='vscode-notebook-cell:/Users/lejaja9/Documents/G14/Friiiiiiiiiday/data_clean.ipynb#ch0000004?line=1'>2</a> raw1_df = pysqldf("SELECT *, strftime('%w', date) AS day_of_week FROM raw1_df")
#
# /Users/lejaja9/Documents/G14/Friiiiiiiiiday/data_clean.ipynb Cell 1' in <lambda>(q)
#       <a href='vscode-notebook-cell:/Users/lejaja9/Documents/G14/Friiiiiiiiiday/data_clean.ipynb#ch0000000?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/lejaja9/Documents/G14/Friiiiiiiiiday/data_clean.ipynb#ch0000000?line=1'>2</a> from pandasql import sqldf
# ----> <a href='vscode-notebook-cell:/Users/lejaja9/Documents/G14/Friiiiiiiiiday/data_clean.ipynb#ch0000000?line=2'>3</a> pysqldf = lambda q: sqldf(q, globals())
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py:156, in sqldf(query, env, db_uri)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=123'>124</a> def sqldf(query, env=None, db_uri='sqlite:///:memory:'):
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=124'>125</a>     """
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=125'>126</a>     Query pandas data frames using sql syntax
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=126'>127</a>     This function is meant for backward compatibility only. New users are encouraged to use the PandaSQL class.
#    (...)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=153'>154</a>     >>> sqldf("select avg(x) from df;", locals())
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=154'>155</a>     """
# --> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=155'>156</a>     return PandaSQL(db_uri)(query, env)
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py:58, in PandaSQL.__call__(self, query, env)
#      <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=55'>56</a>         continue
#      <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=56'>57</a>     self.loaded_tables.add(table_name)
# ---> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=57'>58</a>     write_table(env[table_name], table_name, conn)
#      <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=59'>60</a> try:
#      <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=60'>61</a>     result = read_sql(query, conn)
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py:120, in write_table(df, tablename, conn)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=116'>117</a> with catch_warnings():
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=117'>118</a>     filterwarnings('ignore',
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=118'>119</a>                    message='The provided table name \'%s\' is not found exactly as such in the database' % tablename)
# --> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=119'>120</a>     to_sql(df, name=tablename, con=conn,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandasql/sqldf.py?line=120'>121</a>            index=not any(name is None for name in df.index.names))
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py:717, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=711'>712</a> elif not isinstance(frame, DataFrame):
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=712'>713</a>     raise NotImplementedError(
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=713'>714</a>         "'frame' argument should be either a Series or a DataFrame"
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=714'>715</a>     )
# --> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=716'>717</a> pandas_sql.to_sql(
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=717'>718</a>     frame,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=718'>719</a>     name,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=719'>720</a>     if_exists=if_exists,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=720'>721</a>     index=index,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=721'>722</a>     index_label=index_label,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=722'>723</a>     schema=schema,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=723'>724</a>     chunksize=chunksize,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=724'>725</a>     dtype=dtype,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=725'>726</a>     method=method,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=726'>727</a>     engine=engine,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=727'>728</a>     **engine_kwargs,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=728'>729</a> )
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py:1761, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1748'>1749</a> sql_engine = get_engine(engine)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1750'>1751</a> table = self.prep_table(
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1751'>1752</a>     frame=frame,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1752'>1753</a>     name=name,
#    (...)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1757'>1758</a>     dtype=dtype,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1758'>1759</a> )
# -> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1760'>1761</a> sql_engine.insert_records(
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1761'>1762</a>     table=table,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1762'>1763</a>     con=self.connectable,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1763'>1764</a>     frame=frame,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1764'>1765</a>     name=name,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1765'>1766</a>     index=index,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1766'>1767</a>     schema=schema,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1767'>1768</a>     chunksize=chunksize,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1768'>1769</a>     method=method,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1769'>1770</a>     **engine_kwargs,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1770'>1771</a> )
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1772'>1773</a> self.check_case_sensitive(name=name, schema=schema)
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py:1340, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1336'>1337</a> from sqlalchemy import exc
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1338'>1339</a> try:
# -> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1339'>1340</a>     table.insert(chunksize=chunksize, method=method)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1340'>1341</a> except exc.SQLAlchemyError as err:
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1341'>1342</a>     # GH34431
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1342'>1343</a>     # https://stackoverflow.com/a/67358288/6067848
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1343'>1344</a>     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=1344'>1345</a>     )|inf can not be used with MySQL"""
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py:967, in SQLTable.insert(self, chunksize, method)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=963'>964</a>     break
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=965'>966</a> chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=966'>967</a> exec_insert(conn, keys, chunk_iter)
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py:882, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=869'>870</a> """
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=870'>871</a> Execute SQL statement inserting data
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=871'>872</a>
#    (...)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=878'>879</a>    Each item contains a list of values to be inserted
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=879'>880</a> """
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=880'>881</a> data = [dict(zip(keys, row)) for row in data_iter]
# --> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/io/sql.py?line=881'>882</a> conn.execute(self.table.insert(), data)
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1289, in Connection.execute(self, statement, *multiparams, **params)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1284'>1285</a>     util.raise_(
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1285'>1286</a>         exc.ObjectNotExecutableError(statement), replace_context=err
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1286'>1287</a>     )
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1287'>1288</a> else:
# -> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1288'>1289</a>     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=320'>321</a> def _execute_on_connection(
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=321'>322</a>     self, connection, multiparams, params, execution_options, _force=False
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=322'>323</a> ):
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=323'>324</a>     if _force or self.supports_execution:
# --> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=324'>325</a>         return connection._execute_clauseelement(
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=325'>326</a>             self, multiparams, params, execution_options
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=326'>327</a>         )
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=327'>328</a>     else:
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=328'>329</a>         raise exc.ObjectNotExecutableError(self)
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1481, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1468'>1469</a> compiled_cache = execution_options.get(
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1469'>1470</a>     "compiled_cache", self.engine._compiled_cache
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1470'>1471</a> )
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1472'>1473</a> compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1473'>1474</a>     dialect=dialect,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1474'>1475</a>     compiled_cache=compiled_cache,
#    (...)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1478'>1479</a>     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1479'>1480</a> )
# -> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1480'>1481</a> ret = self._execute_context(
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1481'>1482</a>     dialect,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1482'>1483</a>     dialect.execution_ctx_cls._init_compiled,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1483'>1484</a>     compiled_sql,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1484'>1485</a>     distilled_params,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1485'>1486</a>     execution_options,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1486'>1487</a>     compiled_sql,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1487'>1488</a>     distilled_params,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1488'>1489</a>     elem,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1489'>1490</a>     extracted_params,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1490'>1491</a>     cache_hit=cache_hit,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1491'>1492</a> )
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1492'>1493</a> if has_events:
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1493'>1494</a>     self.dispatch.after_execute(
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1494'>1495</a>         self,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1495'>1496</a>         elem,
#    (...)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1499'>1500</a>         ret,
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1500'>1501</a>     )
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1708, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1705'>1706</a>     raise
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1706'>1707</a> except BaseException as e:
# -> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1707'>1708</a>     self._handle_dbapi_exception(
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1708'>1709</a>         e, util.text_type(statement), parameters, None, None
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1709'>1710</a>     )
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1711'>1712</a> if (
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1712'>1713</a>     self._transaction
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1713'>1714</a>     and not self._transaction.is_active
#    (...)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1717'>1718</a>     )
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1718'>1719</a> ):
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1719'>1720</a>     self._invalid_transaction()
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2030, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2025'>2026</a>         util.raise_(
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2026'>2027</a>             sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2027'>2028</a>         )
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2028'>2029</a>     else:
# -> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2029'>2030</a>         util.raise_(exc_info[1], with_traceback=exc_info[2])
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2031'>2032</a> finally:
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2032'>2033</a>     del self._reentrant_error
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=203'>204</a>     exception.__cause__ = replace_context
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     del exception, replace_context, from_, with_traceback
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1702, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1698'>1699</a>     if conn is None:
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1699'>1700</a>         conn = self._revalidate_connection()
# -> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1701'>1702</a>     context = constructor(
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1702'>1703</a>         dialect, self, conn, execution_options, *args, **kw
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1703'>1704</a>     )
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1704'>1705</a> except (exc.PendingRollbackError, exc.ResourceClosedError):
#    <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1705'>1706</a>     raise
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py:982, in DefaultExecutionContext._init_compiled(cls, dialect, connection, dbapi_connection, execution_options, compiled, parameters, invoked_statement, extracted_parameters, cache_hit)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=975'>976</a>     self.compiled_parameters = [
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=976'>977</a>         compiled.construct_params(
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=977'>978</a>             extracted_parameters=extracted_parameters
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=978'>979</a>         )
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=979'>980</a>     ]
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=980'>981</a> else:
# --> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=981'>982</a>     self.compiled_parameters = [
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=982'>983</a>         compiled.construct_params(
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=983'>984</a>             m,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=984'>985</a>             _group_number=grp,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=985'>986</a>             extracted_parameters=extracted_parameters,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=986'>987</a>         )
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=987'>988</a>         for grp, m in enumerate(parameters)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=988'>989</a>     ]
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=990'>991</a>     self.executemany = len(parameters) > 1
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=992'>993</a> # this must occur before create_cursor() since the statement
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=993'>994</a> # has to be regexed in some cases for server side cursor
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py:983, in <listcomp>(.0)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=975'>976</a>     self.compiled_parameters = [
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=976'>977</a>         compiled.construct_params(
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=977'>978</a>             extracted_parameters=extracted_parameters
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=978'>979</a>         )
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=979'>980</a>     ]
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=980'>981</a> else:
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=981'>982</a>     self.compiled_parameters = [
# --> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=982'>983</a>         compiled.construct_params(
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=983'>984</a>             m,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=984'>985</a>             _group_number=grp,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=985'>986</a>             extracted_parameters=extracted_parameters,
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=986'>987</a>         )
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=987'>988</a>         for grp, m in enumerate(parameters)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=988'>989</a>     ]
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=990'>991</a>     self.executemany = len(parameters) > 1
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=992'>993</a> # this must occur before create_cursor() since the statement
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/engine/default.py?line=993'>994</a> # has to be regexed in some cases for server side cursor
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/compiler.py:973, in SQLCompiler.construct_params(self, params, _group_number, _check, extracted_parameters)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/compiler.py?line=965'>966</a> escaped_name = (
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/compiler.py?line=966'>967</a>     self.escaped_bind_names.get(name, name)
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/compiler.py?line=967'>968</a>     if has_escaped_names
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/compiler.py?line=968'>969</a>     else name
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/compiler.py?line=969'>970</a> )
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/compiler.py?line=971'>972</a> if bindparam.key in params:
# --> <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/compiler.py?line=972'>973</a>     pd[escaped_name] = params[bindparam.key]
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/compiler.py?line=973'>974</a> elif name in params:
#     <a href='file:///~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/sqlalchemy/sql/compiler.py?line=974'>975</a>     pd[escaped_name] = params[name]
#
# KeyboardInterrupt:

# %%
raw0_df = pysqldf("SELECT *, CASE WHEN (day_of_week = 1 OR day_of_week = 2 OR day_of_week = 3 OR day_of_week = 4) AND (hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 3 OR hour_of_day = 23) THEN 'Night' \
    WHEN (day_of_week = 1 OR day_of_week = 2 OR day_of_week = 3 OR day_of_week = 4) AND (hour_of_day = 4 OR hour_of_day = 5) THEN 'Late Night/ Early Morning' \
        WHEN (day_of_week = 1 OR day_of_week = 2 OR day_of_week = 3 OR day_of_week = 4) AND (hour_of_day = 6 OR hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10 OR hour_of_day = 11) THEN 'Morning' \
            WHEN (day_of_week = 1 OR day_of_week = 2 OR day_of_week = 3 OR day_of_week = 4) AND (hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19) THEN 'Afternoon' \
                WHEN (day_of_week = 1 OR day_of_week = 2 OR day_of_week = 3 OR day_of_week = 4) AND (hour_of_day = 20 OR hour_of_day = 21 OR hour_of_day = 22) THEN 'Evening' \
                    WHEN day_of_week = 5 AND (hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 3) THEN 'Night' \
                        WHEN day_of_week = 5 AND (hour_of_day = 4 OR hour_of_day = 5) THEN 'Late Night/ Early Morning' \
                            WHEN day_of_week = 5 AND (hour_of_day = 6 OR hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10) THEN 'Morning' \
                                WHEN day_of_week = 5 AND (hour_of_day = 11 OR hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19) THEN 'Afternoon' \
                                     WHEN day_of_week = 5 AND (hour_of_day = 20 OR hour_of_day = 21 OR hour_of_day = 22 OR hour_of_day = 23) THEN 'Evening' \
                                         WHEN day_of_week = 6 AND (hour_of_day = 3 OR hour_of_day = 4) THEN 'Night' \
                                             WHEN day_of_week = 6 AND (hour_of_day = 5 OR hour_of_day = 6) THEN 'Late Night/ Early Morning' \
                                                 WHEN day_of_week = 6 AND (hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10) THEN 'Morning' \
                                                     WHEN day_of_week = 6 AND (hour_of_day = 11 OR hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16) THEN 'Afternoon' \
                                                         WHEN day_of_week = 6 AND (hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19 OR hour_of_day = 20 OR hour_of_day = 21 OR hour_of_day = 22 OR hour_of_day = 23) THEN 'Evening' \
                                                             WHEN day_of_week = 0 AND hour_of_day = 4 THEN 'Night' \
                                                                 WHEN day_of_week = 0 AND (hour_of_day = 5 OR hour_of_day = 6 OR hour_of_day = 7) THEN 'Late Night/ Early Morning' \
                                                                     WHEN day_of_week = 0 AND (hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10) THEN 'Morning' \
                                                                         WHEN day_of_week = 0 AND (hour_of_day = 11 OR hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19) THEN 'Afternoon' \
                                                                             ELSE 'Evening' END AS 'GROUP' FROM raw0_df")

# %%
raw1_df = pysqldf("SELECT *, CASE WHEN (day_of_week = 1 OR day_of_week = 2 OR day_of_week = 3 OR day_of_week = 4) AND (hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 3 OR hour_of_day = 23) THEN 'Night' \
    WHEN (day_of_week = 1 OR day_of_week = 2 OR day_of_week = 3 OR day_of_week = 4) AND (hour_of_day = 4 OR hour_of_day = 5) THEN 'Late Night/ Early Morning' \
        WHEN (day_of_week = 1 OR day_of_week = 2 OR day_of_week = 3 OR day_of_week = 4) AND (hour_of_day = 6 OR hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10 OR hour_of_day = 11) THEN 'Morning' \
            WHEN (day_of_week = 1 OR day_of_week = 2 OR day_of_week = 3 OR day_of_week = 4) AND (hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19) THEN 'Afternoon' \
                WHEN (day_of_week = 1 OR day_of_week = 2 OR day_of_week = 3 OR day_of_week = 4) AND (hour_of_day = 20 OR hour_of_day = 21 OR hour_of_day = 22) THEN 'Evening' \
                    WHEN day_of_week = 5 AND (hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 3) THEN 'Night' \
                        WHEN day_of_week = 5 AND (hour_of_day = 4 OR hour_of_day = 5) THEN 'Late Night/ Early Morning' \
                            WHEN day_of_week = 5 AND (hour_of_day = 6 OR hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10) THEN 'Morning' \
                                WHEN day_of_week = 5 AND (hour_of_day = 11 OR hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19) THEN 'Afternoon' \
                                     WHEN day_of_week = 5 AND (hour_of_day = 20 OR hour_of_day = 21 OR hour_of_day = 22 OR hour_of_day = 23) THEN 'Evening' \
                                         WHEN day_of_week = 6 AND (hour_of_day = 3 OR hour_of_day = 4) THEN 'Night' \
                                             WHEN day_of_week = 6 AND (hour_of_day = 5 OR hour_of_day = 6) THEN 'Late Night/ Early Morning' \
                                                 WHEN day_of_week = 6 AND (hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10) THEN 'Morning' \
                                                     WHEN day_of_week = 6 AND (hour_of_day = 11 OR hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16) THEN 'Afternoon' \
                                                         WHEN day_of_week = 6 AND (hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19 OR hour_of_day = 20 OR hour_of_day = 21 OR hour_of_day = 22 OR hour_of_day = 23) THEN 'Evening' \
                                                             WHEN day_of_week = 0 AND hour_of_day = 4 THEN 'Night' \
                                                                 WHEN day_of_week = 0 AND (hour_of_day = 5 OR hour_of_day = 6 OR hour_of_day = 7) THEN 'Late Night/ Early Morning' \
                                                                     WHEN day_of_week = 0 AND (hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10) THEN 'Morning' \
                                                                         WHEN day_of_week = 0 AND (hour_of_day = 11 OR hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19) THEN 'Afternoon' \
                                                                             ELSE 'Evening' END AS 'GROUP' FROM raw1_df")

# %%
raw0_df.to_csv('data/raw2_0.csv')
raw1_df.to_csv('data/raw2_1.csv')

# %%
Sunday_df = pd.read_csv('data/Weekdays/Sunday.csv')
Monday_df = pd.read_csv('data/Weekdays/Monday.csv')
Tuesday_df = pd.read_csv('data/Weekdays/Tuesday.csv')
Wednesday_df = pd.read_csv('data/Weekdays/Wednesday.csv')
Thursday_df = pd.read_csv('data/Weekdays/Thursday.csv')
Friday_df = pd.read_csv('data/Weekdays/Friday.csv')
Saturday_df = pd.read_csv('data/Weekdays/Saturday.csv')

# %%
Sunday_df = pysqldf("SELECT *, CASE WHEN hour_of_day = 4 THEN 'Night' \
                                    WHEN hour_of_day = 5 OR hour_of_day = 6 OR hour_of_day = 7 THEN 'Late Night/ Early Morning' \
                                    WHEN hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10 THEN 'Morning' \
                                    WHEN hour_of_day = 11 OR hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19 THEN 'Afternoon' \
                                    ELSE 'Evening' END AS `GROUP` FROM Sunday_df")

# %%
pysqldf("SELECT hour_of_day, `GROUP` FROM Sunday_df GROUP BY hour_of_day, `GROUP`").head(24)
# Out:
#     hour_of_day                      GROUP
# 0             0                    Evening
# 1             1                    Evening
# 2             2                    Evening
# 3             3                    Evening
# 4             4                      Night
# 5             5  Late Night/ Early Morning
# 6             6  Late Night/ Early Morning
# 7             7  Late Night/ Early Morning
# 8             8                    Morning
# 9             9                    Morning
# 10           10                    Morning
# 11           11                  Afternoon
# 12           12                  Afternoon
# 13           13                  Afternoon
# 14           14                  Afternoon
# 15           15                  Afternoon
# 16           16                  Afternoon
# 17           17                  Afternoon
# 18           18                  Afternoon
# 19           19                  Afternoon
# 20           20                    Evening
# 21           21                    Evening
# 22           22                    Evening
# 23           23                    Evening

# %%
Monday_df = pysqldf("SELECT *, CASE WHEN hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 3 OR hour_of_day = 23 THEN 'Night' \
                                    WHEN hour_of_day = 4 OR hour_of_day = 5 THEN 'Late Night/ Early Morning' \
                                    WHEN hour_of_day = 6 OR hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10 OR hour_of_day = 11 THEN 'Morning' \
                                    WHEN hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19 THEN 'Afternoon' \
                                    ELSE 'Evening' END AS `GROUP` FROM Monday_df ")

# %%
pysqldf("SELECT hour_of_day, `GROUP` FROM Monday_df GROUP BY hour_of_day, `GROUP`").head(24)
# Out:
#     hour_of_day                      GROUP
# 0             0                      Night
# 1             1                      Night
# 2             2                      Night
# 3             3                      Night
# 4             4  Late Night/ Early Morning
# 5             5  Late Night/ Early Morning
# 6             6                    Morning
# 7             7                    Morning
# 8             8                    Morning
# 9             9                    Morning
# 10           10                    Morning
# 11           11                    Morning
# 12           12                  Afternoon
# 13           13                  Afternoon
# 14           14                  Afternoon
# 15           15                  Afternoon
# 16           16                  Afternoon
# 17           17                  Afternoon
# 18           18                  Afternoon
# 19           19                  Afternoon
# 20           20                    Evening
# 21           21                    Evening
# 22           22                    Evening
# 23           23                      Night

# %%
Tuesday_df = pysqldf("SELECT *, CASE WHEN hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 3 OR hour_of_day = 23 THEN 'Night' \
                                    WHEN hour_of_day = 4 OR hour_of_day = 5 THEN 'Late Night/ Early Morning' \
                                    WHEN hour_of_day = 6 OR hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10 OR hour_of_day = 11 THEN 'Morning' \
                                    WHEN hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19 THEN 'Afternoon' \
                                    ELSE 'Evening' END AS `GROUP` FROM Tuesday_df ")

# %%
pysqldf("SELECT hour_of_day, `GROUP` FROM Tuesday_df GROUP BY hour_of_day, `GROUP`").head(24)
# Out:
#     hour_of_day                      GROUP
# 0             0                      Night
# 1             1                      Night
# 2             2                      Night
# 3             3                      Night
# 4             4  Late Night/ Early Morning
# 5             5  Late Night/ Early Morning
# 6             6                    Morning
# 7             7                    Morning
# 8             8                    Morning
# 9             9                    Morning
# 10           10                    Morning
# 11           11                    Morning
# 12           12                  Afternoon
# 13           13                  Afternoon
# 14           14                  Afternoon
# 15           15                  Afternoon
# 16           16                  Afternoon
# 17           17                  Afternoon
# 18           18                  Afternoon
# 19           19                  Afternoon
# 20           20                    Evening
# 21           21                    Evening
# 22           22                    Evening
# 23           23                      Night

# %%
Wednesday_df = pysqldf("SELECT *, CASE WHEN hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 3 OR hour_of_day = 23 THEN 'Night' \
                                    WHEN hour_of_day = 4 OR hour_of_day = 5 THEN 'Late Night/ Early Morning' \
                                    WHEN hour_of_day = 6 OR hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10 OR hour_of_day = 11 THEN 'Morning' \
                                    WHEN hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19 THEN 'Afternoon' \
                                    ELSE 'Evening' END AS `GROUP` FROM Wednesday_df ")

# %%
pysqldf("SELECT hour_of_day, `GROUP` FROM Wednesday_df GROUP BY hour_of_day, `GROUP`").head(24)
# Out:
#     hour_of_day                      GROUP
# 0             0                      Night
# 1             1                      Night
# 2             2                      Night
# 3             3                      Night
# 4             4  Late Night/ Early Morning
# 5             5  Late Night/ Early Morning
# 6             6                    Morning
# 7             7                    Morning
# 8             8                    Morning
# 9             9                    Morning
# 10           10                    Morning
# 11           11                    Morning
# 12           12                  Afternoon
# 13           13                  Afternoon
# 14           14                  Afternoon
# 15           15                  Afternoon
# 16           16                  Afternoon
# 17           17                  Afternoon
# 18           18                  Afternoon
# 19           19                  Afternoon
# 20           20                    Evening
# 21           21                    Evening
# 22           22                    Evening
# 23           23                      Night

# %%
Thursday_df = pysqldf("SELECT *, CASE WHEN hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 3 OR hour_of_day = 23 THEN 'Night' \
                                    WHEN hour_of_day = 4 OR hour_of_day = 5 THEN 'Late Night/ Early Morning' \
                                    WHEN hour_of_day = 6 OR hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10 OR hour_of_day = 11 THEN 'Morning' \
                                    WHEN hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19 THEN 'Afternoon' \
                                    ELSE 'Evening' END AS `GROUP` FROM Thursday_df ")

# %%
pysqldf("SELECT hour_of_day, `GROUP` FROM Thursday_df GROUP BY hour_of_day, `GROUP`").head(24)
# Out:
#     hour_of_day                      GROUP
# 0             0                      Night
# 1             1                      Night
# 2             2                      Night
# 3             3                      Night
# 4             4  Late Night/ Early Morning
# 5             5  Late Night/ Early Morning
# 6             6                    Morning
# 7             7                    Morning
# 8             8                    Morning
# 9             9                    Morning
# 10           10                    Morning
# 11           11                    Morning
# 12           12                  Afternoon
# 13           13                  Afternoon
# 14           14                  Afternoon
# 15           15                  Afternoon
# 16           16                  Afternoon
# 17           17                  Afternoon
# 18           18                  Afternoon
# 19           19                  Afternoon
# 20           20                    Evening
# 21           21                    Evening
# 22           22                    Evening
# 23           23                      Night

# %%
Friday_df = pysqldf("SELECT *, CASE WHEN hour_of_day = 0 OR hour_of_day = 1 OR hour_of_day = 2 OR hour_of_day = 3 THEN 'Night' \
                                    WHEN hour_of_day = 4 OR hour_of_day = 5 THEN 'Late Night/ Early Morning' \
                                    WHEN hour_of_day = 6 OR hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10 THEN 'Morning' \
                                    WHEN hour_of_day = 11 OR hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 OR hour_of_day = 17 OR hour_of_day = 18 OR hour_of_day = 19 THEN 'Afternoon' \
                                    ELSE 'Evening' END AS `GROUP` FROM Friday_df ")

# %%
pysqldf("SELECT hour_of_day, `GROUP` FROM Friday_df GROUP BY hour_of_day, `GROUP`").head(24)
# Out:
#     hour_of_day                      GROUP
# 0             0                      Night
# 1             1                      Night
# 2             2                      Night
# 3             3                      Night
# 4             4  Late Night/ Early Morning
# 5             5  Late Night/ Early Morning
# 6             6                    Morning
# 7             7                    Morning
# 8             8                    Morning
# 9             9                    Morning
# 10           10                    Morning
# 11           11                  Afternoon
# 12           12                  Afternoon
# 13           13                  Afternoon
# 14           14                  Afternoon
# 15           15                  Afternoon
# 16           16                  Afternoon
# 17           17                  Afternoon
# 18           18                  Afternoon
# 19           19                  Afternoon
# 20           20                    Evening
# 21           21                    Evening
# 22           22                    Evening
# 23           23                    Evening

# %%
Saturday_df = pysqldf("SELECT *, CASE WHEN hour_of_day = 3 OR hour_of_day = 4 THEN 'Night' \
                                    WHEN hour_of_day = 5 OR hour_of_day = 6 THEN 'Late Night/ Early Morning' \
                                    WHEN hour_of_day = 7 OR hour_of_day = 8 OR hour_of_day = 9 OR hour_of_day = 10 THEN 'Morning' \
                                    WHEN hour_of_day = 11 OR hour_of_day = 12 OR hour_of_day = 13 OR hour_of_day = 14 OR hour_of_day = 15 OR hour_of_day = 16 THEN 'Afternoon' \
                                    ELSE 'Evening' END AS `GROUP` FROM Saturday_df ")

# %%
pysqldf("SELECT hour_of_day, `GROUP` FROM Saturday_df GROUP BY hour_of_day, `GROUP`").head(24)
# Out:
#     hour_of_day                      GROUP
# 0             0                    Evening
# 1             1                    Evening
# 2             2                    Evening
# 3             3                      Night
# 4             4                      Night
# 5             5  Late Night/ Early Morning
# 6             6  Late Night/ Early Morning
# 7             7                    Morning
# 8             8                    Morning
# 9             9                    Morning
# 10           10                    Morning
# 11           11                  Afternoon
# 12           12                  Afternoon
# 13           13                  Afternoon
# 14           14                  Afternoon
# 15           15                  Afternoon
# 16           16                  Afternoon
# 17           17                    Evening
# 18           18                    Evening
# 19           19                    Evening
# 20           20                    Evening
# 21           21                    Evening
# 22           22                    Evening
# 23           23                    Evening

# %%
Sunday_df.to_csv('data/Weekdays/Sunday.csv')
Monday_df.to_csv('data/Weekdays/Monday.csv')
Tuesday_df.to_csv('data/Weekdays/Tuesday.csv')
Wednesday_df.to_csv('data/Weekdays/Wednesday.csv')
Thursday_df.to_csv('data/Weekdays/Thursday.csv')
Friday_df.to_csv('data/Weekdays/Friday.csv')
Saturday_df.to_csv('data/Weekdays/Saturday.csv')
